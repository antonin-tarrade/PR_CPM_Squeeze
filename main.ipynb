# %% [markdown]
# # OBG TO OBJA TRANSFORMATION

# %% [markdown]
# ## Loading model

# %%
# notebook.ipynb
from MeshObjects import *

obj_path = "./models/bunny.obj"

with open(obj_path, 'r') as f:
    objref = Object3D(f, "Reference")
    objref.Show()

objA = AObject3D(objref, "Object A") # M_max

objA.compress(0.1, 15)
objA.show_last_lod () # M0

M_max_prime = objA.decompress() # M_max'
M_max_prime.Show("Reconstructed Object (M_max')")
