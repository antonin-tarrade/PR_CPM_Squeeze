# %% [markdown]
# # OBG TO OBJA TRANSFORMATION

# %% [markdown]
# ## Loading model

# %%
# notebook.ipynb
from MeshObjects import *

obj_path = "./models/bunny.obj"

with open(obj_path, 'r') as f:
    objref = Object3D(f, "Reference")
    objref.Show()

objA = AObject3D(objref, "Object A") # M_max

objA.compress(0.1, 2)
objA.show_last_lod () # M0

M_max_prime = objA.decompress() # M_max'
M_max_prime.Show("Reconstructed Object (M_max')")
# Out:
# Decompression started...
# 1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 15
#      12 objA.compress(0.1, 2)
#      13 objA.show_last_lod () # M0
# ---> 15 M_max_prime = objA.decompress() # M_max'
#      16 M_max_prime.Show("Reconstructed Object (M_max')")
#
# File c:\Users\romai\Documents\GitHub\PR_CPM_Squeeze\MeshObjects.py:151, in AObject3D.decompress(self, nb_decompressions)
#     149 for n in range(nb_decompressions):
#     150     info = self.collapse_info[-(n+1)]
# --> 151     M_n = squeeze_decompression(M_n, info)
#     152 return M_n
#
# File c:\Users\romai\Documents\GitHub\PR_CPM_Squeeze\Decompression.py:13, in squeeze_decompression(Mi_minus_1, infos)
#      11     i += 1
#      12     print(i)
# ---> 13     apply_vertex_split(Mi, info)
#      15 return Mi
#
# File c:\Users\romai\Documents\GitHub\PR_CPM_Squeeze\Decompression.py:24, in apply_vertex_split(Model, collapse_info)
#      22 adjacency = Model.adjacency
#      23 vsplit = collapse_info['v_split']
# ---> 24 w1, w2 = collapse_info['w12']
#      25 v_err = np.array(collapse_info['v_err'])
#      26 neighbors_between = collapse_info['neighbors_between']
#
# ValueError: not enough values to unpack (expected 2, got 0)
