# %% [markdown]
# # OBG TO OBJA TRANSFORMATION

# %% [markdown]
# ## Loading model

# %%
from Compression import *


obj_path = "./models/bunny.obj"

with open(obj_path, 'r') as f:
    objref = Object3D(f,"Reference")
    objref.Show()

objA = AObject3D(objref, "Object A")
objA.compress(0.1,9)
objA.show_lods()
# Out:
# [<Compression.Edge object at 0x118b00040>, <Compression.Edge object at 0x118b80040>, <Compression.Edge object at 0x118a80070>, <Compression.Edge object at 0x118b000a0>, <Compression.Edge object at 0x118b800a0>, <Compression.Edge object at 0x118a800d0>, <Compression.Edge object at 0x118b00100>, <Compression.Edge object at 0x118b80100>, <Compression.Edge object at 0x118a80130>, <Compression.Edge object at 0x118b00160>, <Compression.Edge object at 0x118b80160>, <Compression.Edge object at 0x118a80190>, <Compression.Edge object at 0x118b001c0>, <Compression.Edge object at 0x118b801c0>, <Compression.Edge object at 0x118a801f0>, <Compression.Edge object at 0x118b00220>, <Compression.Edge object at 0x118b80220>, <Compression.Edge object at 0x118a80250>, <Compression.Edge object at 0x118b00280>, <Compression.Edge object at 0x118b80280>, <Compression.Edge object at 0x118a802b0>, <Compression.Edge object at 0x118b002e0>, <Compression.Edge object at 0x118b802e0>, <Compression.Edge object at 0x118a80310>, <Compression.Edge object at 0x118b00340>, <Compression.Edge object at 0x118b80340>, <Compression.Edge object at 0x118a80370>, <Compression.Edge object at 0x118b003a0>, <Compression.Edge object at 0x118b803a0>, <Compression.Edge object at 0x118a803d0>, <Compression.Edge object at 0x118b00400>, <Compression.Edge object at 0x118b80400>, <Compression.Edge object at 0x118a80430>, <Compression.Edge object at 0x118b00460>, <Compression.Edge object at 0x118b80460>, <Compression.Edge object at 0x118a80490>, <Compression.Edge object at 0x118b004c0>, <Compression.Edge object at 0x118b804c0>, <Compression.Edge object at 0x118a804f0>, <Compression.Edge object at 0x118b00520>, <Compression.Edge object at 0x118b80520>, <Compression.Edge object at 0x118a80550>, <Compression.Edge object at 0x118b00580>, <Compression.Edge object at 0x118b80580>, <Compression.Edge object at 0x118a805b0>, <Compression.Edge object at 0x118b005e0>, <Compression.Edge object at 0x118b805e0>, <Compression.Edge object at 0x118a80610>, <Compression.Edge object at 0x118b00640>, <Compression.Edge object at 0x118b80640>, <Compression.Edge object at 0x118a80670>, <Compression.Edge object at 0x118b006a0>, <Compression.Edge object at 0x118b806a0>, <Compression.Edge object at 0x118a806d0>, <Compression.Edge object at 0x118b00700>, <Compression.Edge object at 0x118b80700>, <Compression.Edge object at 0x118a80730>, <Compression.Edge object at 0x118b00760>, <Compression.Edge object at 0x118b80760>, <Compression.Edge object at 0x118a80790>, <Compression.Edge object at 0x118b007c0>, <Compression.Edge object at 0x118b807c0>, <Compression.Edge object at 0x118a807f0>, <Compression.Edge object at 0x118b00820>, <Compression.Edge object at 0x118b80820>, <Compression.Edge object at 0x118a80850>, <Compression.Edge object at 0x118b00880>, <Compression.Edge object at 0x118b80880>, <Compression.Edge object at 0x118a808b0>, <Compression.Edge object at 0x118b008e0>, <Compression.Edge object at 0x118b808e0>, <Compression.Edge object at 0x118a80910>, <Compression.Edge object at 0x118b00940>, <Compression.Edge object at 0x118b80940>, <Compression.Edge object at 0x118a80970>, <Compression.Edge object at 0x118b009a0>, <Compression.Edge object at 0x118b809a0>, <Compression.Edge object at 0x118a809d0>, <Compression.Edge object at 0x118b00a00>, <Compression.Edge object at 0x118b80a00>, <Compression.Edge object at 0x118a80a30>, <Compression.Edge object at 0x118580a30>, <Compression.Edge object at 0x118b00a60>, <Compression.Edge object at 0x118b80a60>, <Compression.Edge object at 0x118a80a90>, <Compression.Edge object at 0x118b00ac0>, <Compression.Edge object at 0x118b80ac0>, <Compression.Edge object at 0x118a80af0>, <Compression.Edge object at 0x118b00b20>, <Compression.Edge object at 0x118b80b20>, <Compression.Edge object at 0x118a80b50>, <Compression.Edge object at 0x118b00b80>, <Compression.Edge object at 0x118b80b80>, <Compression.Edge object at 0x118a80bb0>, <Compression.Edge object at 0x118b00be0>, <Compress ...
# None
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 11
#       8     objref.Show()
#      10 objA = AObject3D(objref, "Object A")
# ---> 11 objA.compress(0.1,9)
#      12 objA.show_lods()
#
# File ~/N7/3A/CSI3D/PR_CPM_Squeeze/Compression.py:29, in AObject3D.compress(self, compression_ratio, nb_compressions)
#      27 for _ in range(nb_compressions):
#      28     last_lod = self.get_last_lod()
# ---> 29     obj, transfo = self.squeeze_compression(last_lod, compression_ratio)
#      30     self.tranformations.append(transfo)
#      31     self.model_lods.append(obj)
#
# File ~/N7/3A/CSI3D/PR_CPM_Squeeze/Compression.py:68, in AObject3D.squeeze_compression(self, Object3D, compression_ratio)
#      65 # boucle de collapses simples
#      66 while len(vertices) > target_vertex_count:
# ---> 68     collapse_edge = sorted_edge[edge_index];
#      69     v1, v2 = collapse_edge
#      71     #  calculer la prédiction du sommet supprimé (par exemple barycentre local)
#
# TypeError: 'NoneType' object is not subscriptable
